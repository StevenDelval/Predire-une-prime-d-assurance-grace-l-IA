# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import kstest,f_oneway,chi2_contingency,kruskal,pointbiserialr,stats

import statsmodels.formula.api as smf
import statsmodels.api as sm

from functions import *

# %%
df = pd.read_csv("dataset_clear.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges     cat_bmi
# 0   19  female  27.900         0    yes  southwest  16884.92400  overweight
# 1   18    male  33.770         1     no  southeast   1725.55230     obesity
# 2   28    male  33.000         3     no  southeast   4449.46200     obesity
# 3   33    male  22.705         0     no  northwest  21984.47061     healthy
# 4   32    male  28.880         0     no  northwest   3866.85520  overweight

# %%
listCharges = pd.DataFrame()
for i in df.loc[df["charges"] < 10000.0].index:
    listCharges = listCharges.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# Out:
# /tmp/ipykernel_5979/250717827.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   listCharges = listCharges.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# /tmp/ipykernel_5979/250717827.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   listCharges = listCharges.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# /tmp/ipykernel_5979/250717827.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   listCharges = listCharges.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# ...

# %%
ListeClear = pd.DataFrame()
for i in listCharges.loc[listCharges["cat_bmi"]!= "healthy"].index:
    ListeClear = ListeClear.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# Out:
# /tmp/ipykernel_5979/3040872127.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ListeClear = ListeClear.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# /tmp/ipykernel_5979/3040872127.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ListeClear = ListeClear.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# /tmp/ipykernel_5979/3040872127.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ListeClear = ListeClear.append(df.loc[i, ["age", "sex", "bmi", "children", "smoker", "region", "charges", "cat_bmi"]])
# ...

# %%
ListeClear.to_csv("test2.csv")

# %%
df['medical'] = None

# %%
for i in df.loc[df["smoker"] == "no"].index:
    if df["charges"][i] > ((df["age"][i] * 78.125) +7500):
        df["medical"][i] = "yes"
    else:
        df["medical"][i] = "no"
# Out:
# /tmp/ipykernel_5979/2372677321.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["medical"][i] = "no"
# /tmp/ipykernel_5979/2372677321.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["medical"][i] = "yes"

# %%
for i in df.loc[df["smoker"] == "yes"].index:
    if df["charges"][i] > ((df["age"][i] * 78.125) +25000):
        df["medical"][i] = "yes"
    else:
        df["medical"][i] = "no"
# Out:
# /tmp/ipykernel_5979/3539538926.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["medical"][i] = "no"
# /tmp/ipykernel_5979/3539538926.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["medical"][i] = "yes"

# %%
df.to_csv("test3.csv")
